# %% [markdown]
# <div class="jumbotron">
#     <center>
#         <h1>Elastic Search</h1>
#         <h2>The heart of the free and open Elastic Stack</h2>
#     </center>
# </div>

# %% [markdown]
# <center>
# <img src="../images/elasticsearch-intro.png"/>
# </center>

# %% [markdown]
# Elasticsearch is a distributed

# %% [markdown]
# RESTful search

# %% [markdown]
# analytics engine

# %% [markdown]
# capable of addressing a growing number of use cases.

# %% [markdown]
# As the heart of the Elastic Stack,
# it centrally stores your data for

# %% [markdown]
# - lightning fast search

# %% [markdown]
# - fine‑tuned relevancy

# %% [markdown]
# - powerful analytics

# %% [markdown]
# that scale with ease.

# %% [markdown]
# # Origin

# %% [markdown]
# It started with a recipe app...

# %% [markdown]
# ![](https://i.imgflip.com/41pcjq.jpg)
# [NicsMeme](https://imgflip.com/i/41pcjq)

# %% [markdown]
# In a London apartment, Shay Banon was looking for a job while his wife attended cooking school at Le Cordon Bleu. In his spare time, he started building a search engine for her growing list of recipes.

# %% [markdown]
# His first iteration was called Compass. The second was Elasticsearch (with [Apache Lucene](https://lucene.apache.org/) under the hood). He open sourced Elasticsearch, created the #elasticsearch IRC channel, and waited for users to appear.

# %% [markdown]
# The response was impressive. Users took to it naturally and easily. Adoption went through the roof, a community started to form, and people noticed — namely Steven Schuurman, Uri Boness, and Simon Willnauer. Together, they founded a search company.

# %% [markdown]
# # Still number 1
# ![](../images/ES-rank.png)
# https://db-engines.com/en/ranking/search+engine

# %% [markdown]
# # Characteristics

# %% [markdown]
# ## Query & Analyze

# %% [markdown]
# ### Search your way
#
# Elasticsearch lets you perform and combine many types of searches — structured, unstructured, geo, metric — any way you want. Start simple with one question and see where it takes you.

# %% [markdown]
# ### Analyze at scale
#
# t's one thing to find the 10 best documents to match your query. But how do you make sense of, say, a billion log lines? Elasticsearch aggregations let you zoom out to explore trends and patterns in your data.

# %% [markdown]
# ## Speed

# %% [markdown]
# ## Elasticsearch is fast. Really, really fast.

# %% [markdown]
# ### Rapid results
# When you get answers instantly, your relationship with your data changes.
#
# You can afford to iterate and cover more ground

# %% [markdown]
# ### Powerful design
# Being this fast isn't easy.
#
# We've implemented:
# - [inverted indices](https://en.wikipedia.org/wiki/Inverted_index) with [finite state transducers](https://en.wikipedia.org/wiki/Finite-state_transducer) for full-text querying
# - [BKD trees](https://en.wikipedia.org/wiki/K-D-B-tree) for storing numeric and geo data,
# - a [column store](https://www.elastic.co/blog/elasticsearch-as-a-column-store) for analytics.

# %% [markdown]
# ### All-inclusive
# And since everything is indexed, you're never left with index envy.
#
# You can leverage and access all of your data at ludicrously awesome speeds.

# %%
import icon
# %icon all_inclusive
#https://google.github.io/material-design-icons/
# Out:
# all_inclusive
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"><i class="material-icons">all_inclusive</i>

# %% [markdown]
# # Scalability

# %% [markdown]
# **Run it on your laptop. Or hundreds of servers with petabytes of data.**
#
# Go from prototype to production seamlessly; you talk to Elasticsearch running on a single node the same way you would in a 300-node cluster.
#
# It scales horizontally to handle kajillions of events per second, while automatically managing how indices and queries are distributed across the cluster for oh-so-smooth operations.

# %% [markdown]
# ![](https://images.contentstack.io/v3/assets/bltefdd0b53724fa2ce/blt8c328002d82e303e/5d0d573477f34fd55839b61f/illustration-elasticsearch-scalability-555.png)

# %% [markdown]
# ## Relevance

# %% [markdown]
# **Search across everything. Find that specific thing.**
#
# Rank your search results based on a variety of factors — from term frequency or recency to popularity and beyond. Mix and match these along with functions to fine tune how your results show up to your users.
#
# And because most of our users are human, Elasticsearch is equipped to handle human mistakes including complexities like typos.

# %% [markdown]
# ![](https://images.contentstack.io/v3/assets/bltefdd0b53724fa2ce/blt15cb7cd2bbb4a45d/5d0d621bb0b16b1c530d3c1a/illustration-elasticsearch-relevance-555.png)

# %% [markdown]
# # Resiliency

# %% [markdown]
# **We cover the bases while you swing for the fences.**
#
# Hardware rebels. Networks partition.
#
# Elasticsearch detects failures to keep your cluster (and your data) safe and available.
#
# With cross-cluster replication, a secondary cluster can spring into action as a hot backup.
#
# Elasticsearch operates in a distributed environment designed from the ground up for perpetual peace of mind.

# %% [markdown]
# ![](https://images.contentstack.io/v3/assets/bltefdd0b53724fa2ce/blt61799e12d10f4581/5e6158f8dc0f1706df255d1c/illustration-elasticsearch-resiliency-555.png)

# %% [markdown]
# ## Use Cases

# %% [markdown]
# Numbers, text, geo, structured, unstructured. All data types are welcome.
#
# Full-text search just scratches the surface of how companies around the world are relying on Elasticsearch to solve a variety of challenges.

# %% [markdown]
# ![](../images/ES-apps.png)

# %% [markdown]
# # Features

# %% [markdown]
# ![](../images/ES-features.png)
# https://www.elastic.co/elasticsearch/features

# %% [markdown]
# ## Client Libraries

# %% [markdown]
# Interact with Elasticsearch in the programming language you choose

# %% [markdown]
# Elasticsearch uses standard RESTful APIs and JSON.
#
# We also build and maintain clients in many languages such as Java, Python, .NET, SQL, and PHP. Plus, our community has contributed many more. They're easy to work with, feel natural to use, and, just like Elasticsearch, don't limit what you might want to do with them.

# %% [markdown]
# # Let's start using it

# %%
# %%bash
# cd /home/nics/Dev/tap/bin
# ./elasticSearch.sh > /tmp/docker.log 2>1 &

# %% [markdown]
# # Does it work ?

# %% [markdown]
# http://localhost:9200/

# %% [markdown]
# ![](https://preview.redd.it/7hgmye86zq631.jpg?width=960&crop=smart&auto=webp&s=65551d7c5cb7afc740699e12a1a8af21fbd7a3ee)
# https://www.reddit.com/r/ProgrammerHumor/comments/c5txc3/jsonmappingexceptions_are_a_pain/

# %% [markdown]
# # Jupyter and Rest Call
#
# ## Ipyrest
#
# [Github](https://github.com/deeplook/ipyrest/)
# [Demo](https://github.com/deeplook/ipyrest/blob/master/examples/meetup.ipynb)

# %% [markdown]
# ### Install

# %%
# !pip install ipyrest
# Out:
# Requirement already satisfied: ipyrest in /home/nics/anaconda3/lib/python3.7/site-packages (0.1.4)
# Requirement already satisfied: vcrpy in /home/nics/anaconda3/lib/python3.7/site-packages (from ipyrest) (4.0.2)
# Requirement already satisfied: numpy in /home/nics/anaconda3/lib/python3.7/site-packages (from ipyrest) (1.18.1)
# Requirement already satisfied: requests in /home/nics/anaconda3/lib/python3.7/site-packages (from ipyrest) (2.22.0)
# Requirement already satisfied: ipyleaflet in /home/nics/anaconda3/lib/python3.7/site-packages (from ipyrest) (0.12.6)
# Requirement already satisfied: pandas in /home/nics/anaconda3/lib/python3.7/site-packages (from ipyrest) (1.0.0)
# Requirement already satisfied: geojson in /home/nics/anaconda3/lib/python3.7/site-packages (from ipyrest) (2.5.0)
# Requirement already satisfied: protobuf in /home/nics/anaconda3/lib/python3.7/site-packages (from ipyrest) (3.11.3)
# Requirement already satisfied: qgrid in /home/nics/anaconda3/lib/python3.7/site-packages (from ipyrest) (1.3.1)
# Requirement already satisfied: timeout-decorator in /home/nics/anaconda3/lib/python3.7/site-packages (from ipyrest) (0.4.1)
# Requirement already satisfied: ipywidgets>=7.4.2 in /home/nics/anaconda3/lib/python3.7/site-packages (from ipyrest) (7.5.1)
# Requirement already satisfied: ipyvolume>=0.5.1 in /home/nics/anaconda3/lib/python3.7/site-packages (from ipyrest) (0.5.2)
# Requirement already satisfied: typing in /home/nics/anaconda3/lib/python3.7/site-packages (from ipyrest) (3.7.4.1)
# Requirement already satisfied: gpxpy in /home/nics/anaconda3/lib/python3.7/site-packages (from ipyrest) (1.4.0)
# Requirement already satisfied: jinja2 in /home/nics/anaconda3/lib/python3.7/site-packages (from ipyrest) (2.11.1)
# Requirement already satisfied: six>=1.5 in /home/nics/anaconda3/lib/python3.7/site-packages (from vcrpy->ipyrest) (1.14.0)
# Requirement already satisfied: wrapt in /home/nics/anaconda3/lib/python3.7/site-packages (from vcrpy->ipyrest) (1.11.2)
# Requirement already satisfied: yarl; python_version >= "3.6" in /home/nics/anaconda3/lib/python3.7/site-packages (from vcrpy->ipyrest) (1.4.2)
# Requirement already satisfied: PyYAML in /home/nics/anaconda3/lib/python3.7/site-packages (from vcrpy->ipyrest) (5.3)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/nics/anaconda3/lib/python3.7/site-packages (from requests->ipyrest) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nics/anaconda3/lib/python3.7/site-packages (from requests->ipyrest) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/nics/anaconda3/lib/python3.7/site-packages (from requests->ipyrest) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/nics/anaconda3/lib/python3.7/site-packages (from requests->ipyrest) (2.8)
# Requirement already satisfied: branca<0.4,>=0.3.1 in /home/nics/anaconda3/lib/python3.7/site-packages (from ipyleaflet->ipyrest) (0.3.1)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /home/nics/anaconda3/lib/python3.7/site-packages (from ipyleaflet->ipyrest) (0.2.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /home/nics/anaconda3/lib/python3.7/site-packages (from pandas->ipyrest) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/nics/anaconda3/lib/python3.7/site-packages (from pandas->ipyrest) (2019.3)
# Requirement already satisfied: setuptools in /home/nics/anaconda3/lib/python3.7/site-packages (from protobuf->ipyrest) (45.1.0.post20200127)
# Requirement already satisfied: notebook>=4.0.0 in /home/nics/anaconda3/lib/python3.7/site-packages (from qgrid->ipyrest) (6.0.3)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /home/nics/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.4.2->ipyrest) (7.12.0)
# Requirement already satisfied: nbformat>=4.2.0 in /home/nics/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.4.2->ipyrest) (5.0.4)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/nics/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.4.2->ipyrest) (5.1.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/nics/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.4.2->ipyrest) (3.5.1)
# Requirement already satisfied: traitlets>=4.3.1 in /home/nics/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.4.2->ipyrest) (4.3.3)
# Requirement already satisfied: pythreejs>=1.0.0 in /home/nics/anaconda3/lib/python3.7/site-packages (from ipyvolume>=0.5.1->ipyrest) (2.2.0)
# Requirement already satisfied: ipywebrtc in /home/nics/anaconda3/lib/python3.7/site-packages (from ipyvolume>=0.5.1->ipyrest) (0.5.0)
# Requirement already satisfied: Pillow in /home/nics/anaconda3/lib/python3.7/site-packages (from ipyvolume>=0.5.1->ipyrest) (7.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/nics/anaconda3/lib/python3.7/site-packages (from jinja2->ipyrest) (1.1.1)
# Requirement already satisfied: multidict>=4.0 in /home/nics/anaconda3/lib/python3.7/site-packages (from yarl; python_version >= "3.6"->vcrpy->ipyrest) (4.7.6)
# Requirement already satisfied: Send2Trash in /home/nics/anaconda3/lib/python3.7/site-packages (from notebook>=4.0.0->qgrid->ipyrest) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in /home/nics/anaconda3/lib/python3.7/site-packages (from notebook>=4.0.0->qgrid->ipyrest) (18.1.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /home/nics/anaconda3/lib/python3.7/site-packages (from notebook>=4.0.0->qgrid->ipyrest) (4.6.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in /home/nics/anaconda3/lib/python3.7/site-packages (from notebook>=4.0.0->qgrid->ipyrest) (5.3.4)
# Requirement already satisfied: tornado>=5.0 in /home/nics/anaconda3/lib/python3.7/site-packages (from notebook>=4.0.0->qgrid->ipyrest) (6.0.3)
# Requirement already satisfied: terminado>=0.8.1 in /home/nics/anaconda3/lib/python3.7/site-packages (from notebook>=4.0.0->qgrid->ipyrest) (0.8.3)
# Requirement already satisfied: prometheus-client in /home/nics/anaconda3/lib/python3.7/site-packages (from notebook>=4.0.0->qgrid->ipyrest) (0.7.1)
# Requirement already satisfied: ipython-genutils in /home/nics/anaconda3/lib/python3.7/site-packages (from notebook>=4.0.0->qgrid->ipyrest) (0.2.0)
# Requirement already satisfied: nbconvert in /home/nics/anaconda3/lib/python3.7/site-packages (from notebook>=4.0.0->qgrid->ipyrest) (5.6.1)
# Requirement already satisfied: decorator in /home/nics/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.4.2->ipyrest) (4.4.1)
# Requirement already satisfied: pygments in /home/nics/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.4.2->ipyrest) (2.5.2)
# Requirement already satisfied: jedi>=0.10 in /home/nics/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.4.2->ipyrest) (0.16.0)
# Requirement already satisfied: pickleshare in /home/nics/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.4.2->ipyrest) (0.7.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /home/nics/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.4.2->ipyrest) (4.8.0)
# Requirement already satisfied: backcall in /home/nics/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.4.2->ipyrest) (0.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/nics/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.4.2->ipyrest) (3.0.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/nics/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.4.2->ipyrest) (3.2.0)
# Requirement already satisfied: ipydatawidgets>=1.1.1 in /home/nics/anaconda3/lib/python3.7/site-packages (from pythreejs>=1.0.0->ipyvolume>=0.5.1->ipyrest) (4.0.1)
# Requirement already satisfied: bleach in /home/nics/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.0.0->qgrid->ipyrest) (3.1.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/nics/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.0.0->qgrid->ipyrest) (0.3)
# Requirement already satisfied: testpath in /home/nics/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.0.0->qgrid->ipyrest) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/nics/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.0.0->qgrid->ipyrest) (1.4.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/nics/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.0.0->qgrid->ipyrest) (0.8.4)
# Requirement already satisfied: defusedxml in /home/nics/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.0.0->qgrid->ipyrest) (0.6.0)
# Requirement already satisfied: parso>=0.5.2 in /home/nics/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.4.2->ipyrest) (0.6.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/nics/anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.4.2->ipyrest) (0.6.0)
# Requirement already satisfied: wcwidth in /home/nics/anaconda3/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.4.2->ipyrest) (0.1.8)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/nics/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.4.2->ipyrest) (0.15.7)
# Requirement already satisfied: attrs>=17.4.0 in /home/nics/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.4.2->ipyrest) (19.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /home/nics/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.4.2->ipyrest) (1.5.0)
# Requirement already satisfied: webencodings in /home/nics/anaconda3/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.0.0->qgrid->ipyrest) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in /home/nics/anaconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.4.2->ipyrest) (2.1.0)

# %% [markdown]
# ### Import

# %%
from ipyrest import Api

# %% [markdown]
# # Run a Query

# %%
Api('http://localhost:9200/',click_send=True)
# Out:
# Api(children=(HBox(children=(Dropdown(layout=Layout(width='100%px'), options=('GET', 'POST', 'PUT', 'PATCH', '…

# %% [markdown]
# # Let's put something in
#
# ## A single record

# %%
doc = {
  "name": "John Doe"
}


url="http://localhost:9200/customers/_doc/1"
Api(url,method="PUT", data=doc)
# Out:
# Api(children=(HBox(children=(Dropdown(index=2, layout=Layout(width='100%px'), options=('GET', 'POST', 'PUT', '…

# %% [markdown]
# # And get it back

# %%
url="http://localhost:9200/customers/_doc/1"
Api(url,click_send=True)
# Out:
# Api(children=(HBox(children=(Dropdown(layout=Layout(width='100%px'), options=('GET', 'POST', 'PUT', 'PATCH', '…

# %% [markdown]
# # Index more
#
# Bulk Upload allows to upload multiple records, usually batch with 1000 are a good starting point

# %% [markdown]
# ```json
# {
#   "account_number": 1,
#   "balance": 39225,
#   "firstname": "Amber",
#   "lastname": "Duke",
#   "age": 32,
#   "gender": "M",
#   "address": "880 Holmes Lane",
#   "employer": "Pyrami",
#   "email": "amberduke@pyrami.com",
#   "city": "Brogan",
#   "state": "IL"
# }
# ```
# [Accounts.json](../elasticsearch/dataset/accounts.json)

# %%
# !curl -H "Content-Type: application/json" -XPOST "localhost:9200/bank/_bulk?pretty&refresh" --data-binary "@../elasticsearch/dataset/accounts.json"
# Out:
# {
#   "took" : 672,
#   "errors" : false,
#   "items" : [
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "1",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 0,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "6",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 1,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "13",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 2,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "18",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 3,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "20",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 4,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "25",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 5,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "32",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 6,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "37",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 7,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "44",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 8,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "49",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 9,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "51",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 10,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "56",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 11,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "63",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 12,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "68",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 13,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "70",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 14,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "75",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 15,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "82",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 16,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "87",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 17,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "94",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 18,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "99",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 19,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "102",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 20,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "107",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 21,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "114",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 22,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "119",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 23,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "121",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 24,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "126",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 25,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "133",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 26,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "138",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 27,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "140",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 28,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "145",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 29,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "152",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 30,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "157",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 31,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "164",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 32,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "169",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 33,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "171",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 34,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "176",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 35,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "183",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 36,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "188",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 37,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "190",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 38,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "195",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 39,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "203",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 40,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "208",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 41,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "210",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 42,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "215",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 43,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "222",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 44,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "227",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 45,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "234",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 46,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "239",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 47,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "241",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 48,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "246",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 49,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "253",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 50,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "258",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 51,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "260",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 52,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "265",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 53,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "272",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 54,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "277",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 55,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "284",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 56,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "289",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 57,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "291",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 58,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "296",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 59,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "304",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 60,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "309",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 61,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "311",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 62,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "316",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 63,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "323",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 64,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "328",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 65,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "330",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 66,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "335",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 67,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "342",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 68,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "347",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 69,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "354",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 70,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "359",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 71,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "361",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 72,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "366",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 73,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "373",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 74,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "378",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 75,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "380",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 76,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "385",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 77,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "392",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 78,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "397",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 79,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "400",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 80,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "405",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 81,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "412",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 82,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "417",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 83,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "424",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 84,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "429",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 85,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "431",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 86,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "436",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 87,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "443",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 88,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "448",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 89,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "450",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 90,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "455",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 91,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "462",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 92,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "467",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 93,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "474",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 94,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "479",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 95,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "481",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 96,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "486",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 97,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "493",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 98,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "498",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 99,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "501",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 100,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "506",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 101,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "513",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 102,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "518",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 103,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "520",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 104,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "525",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 105,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "532",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 106,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "537",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 107,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "544",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 108,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "549",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 109,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "551",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 110,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "556",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 111,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "563",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 112,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "568",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 113,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "570",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 114,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "575",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 115,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "582",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 116,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "587",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 117,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "594",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 118,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "599",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 119,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "602",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 120,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "607",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 121,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "614",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 122,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "619",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 123,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "621",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
# ...
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 958,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "798",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 959,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "801",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 960,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "806",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 961,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "813",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 962,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "818",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 963,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "820",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 964,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "825",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 965,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "832",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 966,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "837",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 967,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "844",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 968,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "849",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 969,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "851",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 970,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "856",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 971,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "863",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 972,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "868",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 973,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "870",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 974,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "875",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 975,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "882",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 976,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "887",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 977,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "894",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 978,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "899",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 979,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "902",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 980,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "907",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 981,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "914",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 982,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "919",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 983,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "921",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 984,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "926",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 985,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "933",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 986,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "938",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 987,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "940",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 988,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "945",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 989,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "952",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 990,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "957",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 991,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "964",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 992,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "969",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 993,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "971",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 994,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "976",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 995,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "983",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 996,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "988",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 997,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "990",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 998,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     },
#     {
#       "index" : {
#         "_index" : "bank",
#         "_type" : "_doc",
#         "_id" : "995",
#         "_version" : 1,
#         "result" : "created",
#         "forced_refresh" : true,
#         "_shards" : {
#           "total" : 2,
#           "successful" : 1,
#           "failed" : 0
#         },
#         "_seq_no" : 999,
#         "_primary_term" : 1,
#         "status" : 201
#       }
#     }
#   ]
# }

# %% [markdown]
# # Requests
#
# https://requests.readthedocs.io/en/master/

# %% [markdown]
# ## Install

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /home/nics/anaconda3/lib/python3.7/site-packages (2.22.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/nics/anaconda3/lib/python3.7/site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/nics/anaconda3/lib/python3.7/site-packages (from requests) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nics/anaconda3/lib/python3.7/site-packages (from requests) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/nics/anaconda3/lib/python3.7/site-packages (from requests) (2.8)

# %% [markdown]
# ## Import

# %%
import requests

# %% [markdown]
# ## Index Status

# %%
r = requests.get('http://localhost:9200/_cat/indices?v')
r.text
# Out:
# 'health status index     uuid                   pri rep docs.count docs.deleted store.size pri.store.size\nyellow open   bank      d7IclMwWTreU_beYazEjhw   1   1       1000            0    381.8kb        381.8kb\nyellow open   customers zL9QLvXNSdGwPtzfip6ttw   1   1          1            0      3.5kb          3.5kb\n'

# %% [markdown]
# # Search
# Once you have ingested some data into an Elasticsearch index, you can search it by sending requests to the _search endpoint. To access the full suite of search capabilities, you use the Elasticsearch Query DSL to specify the search criteria in the request body. You specify the name of the index you want to search in the request URI.
#
# For example, the following request retrieves all documents in the bank index sorted by account number:

# %%
data = """{
  "query": { "match_all": {} },
  "sort": [
    { "account_number": "asc" }
  ]
}"""

url="http://localhost:9200/bank/_search?pretty"

headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}

r = requests.post(url,data=data, headers=headers)

r.json()
# Out:
# {'took': 59,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1000, 'relation': 'eq'},
#   'max_score': None,
#   'hits': [{'_index': 'bank',
#     '_type': '_doc',
#     '_id': '0',
#     '_score': None,
#     '_source': {'account_number': 0,
#      'balance': 16623,
#      'firstname': 'Bradshaw',
#      'lastname': 'Mckenzie',
#      'age': 29,
#      'gender': 'F',
#      'address': '244 Columbus Place',
#      'employer': 'Euron',
#      'email': 'bradshawmckenzie@euron.com',
#      'city': 'Hobucken',
#      'state': 'CO'},
#     'sort': [0]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '1',
#     '_score': None,
#     '_source': {'account_number': 1,
#      'balance': 39225,
#      'firstname': 'Amber',
#      'lastname': 'Duke',
#      'age': 32,
#      'gender': 'M',
#      'address': '880 Holmes Lane',
#      'employer': 'Pyrami',
#      'email': 'amberduke@pyrami.com',
#      'city': 'Brogan',
#      'state': 'IL'},
#     'sort': [1]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '2',
#     '_score': None,
#     '_source': {'account_number': 2,
#      'balance': 28838,
#      'firstname': 'Roberta',
#      'lastname': 'Bender',
#      'age': 22,
#      'gender': 'F',
#      'address': '560 Kingsway Place',
#      'employer': 'Chillium',
#      'email': 'robertabender@chillium.com',
#      'city': 'Bennett',
#      'state': 'LA'},
#     'sort': [2]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '3',
#     '_score': None,
#     '_source': {'account_number': 3,
#      'balance': 44947,
#      'firstname': 'Levine',
#      'lastname': 'Burks',
#      'age': 26,
#      'gender': 'F',
#      'address': '328 Wilson Avenue',
#      'employer': 'Amtap',
#      'email': 'levineburks@amtap.com',
#      'city': 'Cochranville',
#      'state': 'HI'},
#     'sort': [3]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '4',
#     '_score': None,
#     '_source': {'account_number': 4,
#      'balance': 27658,
#      'firstname': 'Rodriquez',
#      'lastname': 'Flores',
#      'age': 31,
#      'gender': 'F',
#      'address': '986 Wyckoff Avenue',
#      'employer': 'Tourmania',
#      'email': 'rodriquezflores@tourmania.com',
#      'city': 'Eastvale',
#      'state': 'HI'},
#     'sort': [4]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '5',
#     '_score': None,
#     '_source': {'account_number': 5,
#      'balance': 29342,
#      'firstname': 'Leola',
#      'lastname': 'Stewart',
#      'age': 30,
#      'gender': 'F',
#      'address': '311 Elm Place',
#      'employer': 'Diginetic',
#      'email': 'leolastewart@diginetic.com',
#      'city': 'Fairview',
#      'state': 'NJ'},
#     'sort': [5]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '6',
#     '_score': None,
#     '_source': {'account_number': 6,
#      'balance': 5686,
#      'firstname': 'Hattie',
#      'lastname': 'Bond',
#      'age': 36,
#      'gender': 'M',
#      'address': '671 Bristol Street',
#      'employer': 'Netagy',
#      'email': 'hattiebond@netagy.com',
#      'city': 'Dante',
#      'state': 'TN'},
#     'sort': [6]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '7',
#     '_score': None,
#     '_source': {'account_number': 7,
#      'balance': 39121,
#      'firstname': 'Levy',
#      'lastname': 'Richard',
#      'age': 22,
#      'gender': 'M',
#      'address': '820 Logan Street',
#      'employer': 'Teraprene',
#      'email': 'levyrichard@teraprene.com',
#      'city': 'Shrewsbury',
#      'state': 'MO'},
#     'sort': [7]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '8',
#     '_score': None,
#     '_source': {'account_number': 8,
#      'balance': 48868,
#      'firstname': 'Jan',
#      'lastname': 'Burns',
#      'age': 35,
#      'gender': 'M',
#      'address': '699 Visitation Place',
#      'employer': 'Glasstep',
#      'email': 'janburns@glasstep.com',
#      'city': 'Wakulla',
#      'state': 'AZ'},
#     'sort': [8]},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '9',
#     '_score': None,
#     '_source': {'account_number': 9,
#      'balance': 24776,
#      'firstname': 'Opal',
#      'lastname': 'Meadows',
#      'age': 39,
#      'gender': 'M',
#      'address': '963 Neptune Avenue',
#      'employer': 'Cedward',
#      'email': 'opalmeadows@cedward.com',
#      'city': 'Olney',
#      'state': 'OH'},
#     'sort': [9]}]}}

# %% [markdown]
# ## Search String
#
# To search for specific terms within a field, you can use a match query. For example, the following request searches the address field to find customers whose addresses contain mill or lane:

# %%
data = """{
  "query": { "match": { "address": "mill lane" } }
}"""

url="http://localhost:9200/bank/_search?pretty"

headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}

r = requests.post(url,data=data, headers=headers)
r.json()
# Out:
# {'took': 24,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 19, 'relation': 'eq'},
#   'max_score': 9.507477,
#   'hits': [{'_index': 'bank',
#     '_type': '_doc',
#     '_id': '136',
#     '_score': 9.507477,
#     '_source': {'account_number': 136,
#      'balance': 45801,
#      'firstname': 'Winnie',
#      'lastname': 'Holland',
#      'age': 38,
#      'gender': 'M',
#      'address': '198 Mill Lane',
#      'employer': 'Neteria',
#      'email': 'winnieholland@neteria.com',
#      'city': 'Urie',
#      'state': 'IL'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '970',
#     '_score': 5.4032025,
#     '_source': {'account_number': 970,
#      'balance': 19648,
#      'firstname': 'Forbes',
#      'lastname': 'Wallace',
#      'age': 28,
#      'gender': 'M',
#      'address': '990 Mill Road',
#      'employer': 'Pheast',
#      'email': 'forbeswallace@pheast.com',
#      'city': 'Lopezo',
#      'state': 'AK'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '345',
#     '_score': 5.4032025,
#     '_source': {'account_number': 345,
#      'balance': 9812,
#      'firstname': 'Parker',
#      'lastname': 'Hines',
#      'age': 38,
#      'gender': 'M',
#      'address': '715 Mill Avenue',
#      'employer': 'Baluba',
#      'email': 'parkerhines@baluba.com',
#      'city': 'Blackgum',
#      'state': 'KY'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '472',
#     '_score': 5.4032025,
#     '_source': {'account_number': 472,
#      'balance': 25571,
#      'firstname': 'Lee',
#      'lastname': 'Long',
#      'age': 32,
#      'gender': 'F',
#      'address': '288 Mill Street',
#      'employer': 'Comverges',
#      'email': 'leelong@comverges.com',
#      'city': 'Movico',
#      'state': 'MT'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '1',
#     '_score': 4.1042743,
#     '_source': {'account_number': 1,
#      'balance': 39225,
#      'firstname': 'Amber',
#      'lastname': 'Duke',
#      'age': 32,
#      'gender': 'M',
#      'address': '880 Holmes Lane',
#      'employer': 'Pyrami',
#      'email': 'amberduke@pyrami.com',
#      'city': 'Brogan',
#      'state': 'IL'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '70',
#     '_score': 4.1042743,
#     '_source': {'account_number': 70,
#      'balance': 38172,
#      'firstname': 'Deidre',
#      'lastname': 'Thompson',
#      'age': 33,
#      'gender': 'F',
#      'address': '685 School Lane',
#      'employer': 'Netplode',
#      'email': 'deidrethompson@netplode.com',
#      'city': 'Chestnut',
#      'state': 'GA'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '556',
#     '_score': 4.1042743,
#     '_source': {'account_number': 556,
#      'balance': 36420,
#      'firstname': 'Collier',
#      'lastname': 'Odonnell',
#      'age': 35,
#      'gender': 'M',
#      'address': '591 Nolans Lane',
#      'employer': 'Sultraxin',
#      'email': 'collierodonnell@sultraxin.com',
#      'city': 'Fulford',
#      'state': 'MD'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '568',
#     '_score': 4.1042743,
#     '_source': {'account_number': 568,
#      'balance': 36628,
#      'firstname': 'Lesa',
#      'lastname': 'Maynard',
#      'age': 29,
#      'gender': 'F',
#      'address': '295 Whitty Lane',
#      'employer': 'Coash',
#      'email': 'lesamaynard@coash.com',
#      'city': 'Broadlands',
#      'state': 'VT'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '715',
#     '_score': 4.1042743,
#     '_source': {'account_number': 715,
#      'balance': 23734,
#      'firstname': 'Tammi',
#      'lastname': 'Hodge',
#      'age': 24,
#      'gender': 'M',
#      'address': '865 Church Lane',
#      'employer': 'Netur',
#      'email': 'tammihodge@netur.com',
#      'city': 'Lacomb',
#      'state': 'KS'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '449',
#     '_score': 4.1042743,
#     '_source': {'account_number': 449,
#      'balance': 41950,
#      'firstname': 'Barnett',
#      'lastname': 'Cantrell',
#      'age': 39,
#      'gender': 'F',
#      'address': '945 Bedell Lane',
#      'employer': 'Zentility',
#      'email': 'barnettcantrell@zentility.com',
#      'city': 'Swartzville',
#      'state': 'ND'}}]}}

# %% [markdown]
# # Search Exact
#
# To perform a phrase search rather than matching individual terms, you use match_phrase instead of match. For example, the following request only matches addresses that contain the phrase mill lane:

# %%
data = """{
  "query": { "match_phrase": { "address": "mill lane" } }
}"""

url="http://localhost:9200/bank/_search?pretty"

headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}

r = requests.post(url,data=data, headers=headers)
r.json()
# Out:
# {'took': 8,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1, 'relation': 'eq'},
#   'max_score': 9.507477,
#   'hits': [{'_index': 'bank',
#     '_type': '_doc',
#     '_id': '136',
#     '_score': 9.507477,
#     '_source': {'account_number': 136,
#      'balance': 45801,
#      'firstname': 'Winnie',
#      'lastname': 'Holland',
#      'age': 38,
#      'gender': 'M',
#      'address': '198 Mill Lane',
#      'employer': 'Neteria',
#      'email': 'winnieholland@neteria.com',
#      'city': 'Urie',
#      'state': 'IL'}}]}}

# %% [markdown]
# ## Combine Multiple Query
#
# To construct more complex queries, you can use a bool query to combine multiple query criteria. You can designate criteria as required (must match), desirable (should match), or undesirable (must not match).
#
# For example, the following request searches the bank index for accounts that belong to customers who are 40 years old, but excludes anyone who lives in Idaho (ID)

# %%
data = """{

  "query": {
    "bool": {
      "must": [
        { "match": { "age": "40" } }
      ],
      "must_not": [
        { "match": { "state": "ID" } }
      ]
    }
  }
}"""

url="http://localhost:9200/bank/_search?pretty"

headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}

r = requests.post(url,data=data, headers=headers)
r.json()
# Out:
# {'took': 37,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 43, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'bank',
#     '_type': '_doc',
#     '_id': '474',
#     '_score': 1.0,
#     '_source': {'account_number': 474,
#      'balance': 35896,
#      'firstname': 'Obrien',
#      'lastname': 'Walton',
#      'age': 40,
#      'gender': 'F',
#      'address': '192 Ide Court',
#      'employer': 'Suremax',
#      'email': 'obrienwalton@suremax.com',
#      'city': 'Crucible',
#      'state': 'UT'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '479',
#     '_score': 1.0,
#     '_source': {'account_number': 479,
#      'balance': 31865,
#      'firstname': 'Cameron',
#      'lastname': 'Ross',
#      'age': 40,
#      'gender': 'M',
#      'address': '904 Bouck Court',
#      'employer': 'Telpod',
#      'email': 'cameronross@telpod.com',
#      'city': 'Nord',
#      'state': 'MO'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '549',
#     '_score': 1.0,
#     '_source': {'account_number': 549,
#      'balance': 1932,
#      'firstname': 'Jacqueline',
#      'lastname': 'Maxwell',
#      'age': 40,
#      'gender': 'M',
#      'address': '444 Schenck Place',
#      'employer': 'Fuelworks',
#      'email': 'jacquelinemaxwell@fuelworks.com',
#      'city': 'Oretta',
#      'state': 'OR'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '878',
#     '_score': 1.0,
#     '_source': {'account_number': 878,
#      'balance': 49159,
#      'firstname': 'Battle',
#      'lastname': 'Blackburn',
#      'age': 40,
#      'gender': 'F',
#      'address': '234 Hendrix Street',
#      'employer': 'Zilphur',
#      'email': 'battleblackburn@zilphur.com',
#      'city': 'Wanamie',
#      'state': 'PA'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '885',
#     '_score': 1.0,
#     '_source': {'account_number': 885,
#      'balance': 31661,
#      'firstname': 'Valdez',
#      'lastname': 'Roberson',
#      'age': 40,
#      'gender': 'F',
#      'address': '227 Scholes Street',
#      'employer': 'Delphide',
#      'email': 'valdezroberson@delphide.com',
#      'city': 'Chilton',
#      'state': 'MT'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '948',
#     '_score': 1.0,
#     '_source': {'account_number': 948,
#      'balance': 37074,
#      'firstname': 'Sargent',
#      'lastname': 'Powers',
#      'age': 40,
#      'gender': 'M',
#      'address': '532 Fiske Place',
#      'employer': 'Accuprint',
#      'email': 'sargentpowers@accuprint.com',
#      'city': 'Umapine',
#      'state': 'AK'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '998',
#     '_score': 1.0,
#     '_source': {'account_number': 998,
#      'balance': 16869,
#      'firstname': 'Letha',
#      'lastname': 'Baker',
#      'age': 40,
#      'gender': 'F',
#      'address': '206 Llama Court',
#      'employer': 'Dognosis',
#      'email': 'lethabaker@dognosis.com',
#      'city': 'Dunlo',
#      'state': 'WV'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '40',
#     '_score': 1.0,
#     '_source': {'account_number': 40,
#      'balance': 33882,
#      'firstname': 'Pace',
#      'lastname': 'Molina',
#      'age': 40,
#      'gender': 'M',
#      'address': '263 Ovington Court',
#      'employer': 'Cytrak',
#      'email': 'pacemolina@cytrak.com',
#      'city': 'Silkworth',
#      'state': 'OR'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '165',
#     '_score': 1.0,
#     '_source': {'account_number': 165,
#      'balance': 18956,
#      'firstname': 'Sims',
#      'lastname': 'Mckay',
#      'age': 40,
#      'gender': 'F',
#      'address': '205 Jackson Street',
#      'employer': 'Comtour',
#      'email': 'simsmckay@comtour.com',
#      'city': 'Tilden',
#      'state': 'DC'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '177',
#     '_score': 1.0,
#     '_source': {'account_number': 177,
#      'balance': 48972,
#      'firstname': 'Harris',
#      'lastname': 'Gross',
#      'age': 40,
#      'gender': 'F',
#      'address': '468 Suydam Street',
#      'employer': 'Kidstock',
#      'email': 'harrisgross@kidstock.com',
#      'city': 'Yettem',
#      'state': 'KY'}}]}}

# %% [markdown]
# ## Filters
#
# Each must, should, and must_not element in a Boolean query is referred to as a query clause.
#
# How well a document meets the criteria in each must or should clause contributes to the document’s relevance score. The higher the score, the better the document matches your search criteria.
#
# By default, Elasticsearch returns documents ranked by these relevance scores.
#
# The criteria in a must_not clause is treated as a filter. It affects whether or not the document is included in the results, but does not contribute to how documents are scored. You can also explicitly specify arbitrary filters to include or exclude documents based on structured data.
#
# For example, the following request uses a range filter to limit the results to accounts with a balance between 20,000 and 30,000 (inclusive).

# %%
data = """{
  "query": {
    "bool": {
      "must": { "match_all": {} },
      "filter": {
        "range": {
          "balance": {
            "gte": 20000,
            "lte": 30000
          }
        }
      }
    }
  }
}"""

url="http://localhost:9200/bank/_search?pretty"

headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}

r = requests.post(url,data=data, headers=headers)
r.json()
# Out:
# {'took': 13,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 217, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'bank',
#     '_type': '_doc',
#     '_id': '49',
#     '_score': 1.0,
#     '_source': {'account_number': 49,
#      'balance': 29104,
#      'firstname': 'Fulton',
#      'lastname': 'Holt',
#      'age': 23,
#      'gender': 'F',
#      'address': '451 Humboldt Street',
#      'employer': 'Anocha',
#      'email': 'fultonholt@anocha.com',
#      'city': 'Sunriver',
#      'state': 'RI'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '102',
#     '_score': 1.0,
#     '_source': {'account_number': 102,
#      'balance': 29712,
#      'firstname': 'Dena',
#      'lastname': 'Olson',
#      'age': 27,
#      'gender': 'F',
#      'address': '759 Newkirk Avenue',
#      'employer': 'Hinway',
#      'email': 'denaolson@hinway.com',
#      'city': 'Choctaw',
#      'state': 'NJ'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '133',
#     '_score': 1.0,
#     '_source': {'account_number': 133,
#      'balance': 26135,
#      'firstname': 'Deena',
#      'lastname': 'Richmond',
#      'age': 36,
#      'gender': 'F',
#      'address': '646 Underhill Avenue',
#      'employer': 'Sunclipse',
#      'email': 'deenarichmond@sunclipse.com',
#      'city': 'Austinburg',
#      'state': 'SC'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '140',
#     '_score': 1.0,
#     '_source': {'account_number': 140,
#      'balance': 26696,
#      'firstname': 'Cotton',
#      'lastname': 'Christensen',
#      'age': 32,
#      'gender': 'M',
#      'address': '878 Schermerhorn Street',
#      'employer': 'Prowaste',
#      'email': 'cottonchristensen@prowaste.com',
#      'city': 'Mayfair',
#      'state': 'LA'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '203',
#     '_score': 1.0,
#     '_source': {'account_number': 203,
#      'balance': 21890,
#      'firstname': 'Eve',
#      'lastname': 'Wyatt',
#      'age': 33,
#      'gender': 'M',
#      'address': '435 Furman Street',
#      'employer': 'Assitia',
#      'email': 'evewyatt@assitia.com',
#      'city': 'Jamestown',
#      'state': 'MN'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '239',
#     '_score': 1.0,
#     '_source': {'account_number': 239,
#      'balance': 25719,
#      'firstname': 'Chang',
#      'lastname': 'Boyer',
#      'age': 36,
#      'gender': 'M',
#      'address': '895 Brigham Street',
#      'employer': 'Qaboos',
#      'email': 'changboyer@qaboos.com',
#      'city': 'Belgreen',
#      'state': 'NH'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '241',
#     '_score': 1.0,
#     '_source': {'account_number': 241,
#      'balance': 25379,
#      'firstname': 'Schroeder',
#      'lastname': 'Harrington',
#      'age': 26,
#      'gender': 'M',
#      'address': '610 Tapscott Avenue',
#      'employer': 'Otherway',
#      'email': 'schroederharrington@otherway.com',
#      'city': 'Ebro',
#      'state': 'TX'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '246',
#     '_score': 1.0,
#     '_source': {'account_number': 246,
#      'balance': 28405,
#      'firstname': 'Katheryn',
#      'lastname': 'Foster',
#      'age': 21,
#      'gender': 'F',
#      'address': '259 Kane Street',
#      'employer': 'Quantalia',
#      'email': 'katherynfoster@quantalia.com',
#      'city': 'Bath',
#      'state': 'TX'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '253',
#     '_score': 1.0,
#     '_source': {'account_number': 253,
#      'balance': 20240,
#      'firstname': 'Melissa',
#      'lastname': 'Gould',
#      'age': 31,
#      'gender': 'M',
#      'address': '440 Fuller Place',
#      'employer': 'Buzzopia',
#      'email': 'melissagould@buzzopia.com',
#      'city': 'Lumberton',
#      'state': 'MD'}},
#    {'_index': 'bank',
#     '_type': '_doc',
#     '_id': '277',
#     '_score': 1.0,
#     '_source': {'account_number': 277,
#      'balance': 29564,
#      'firstname': 'Romero',
#      'lastname': 'Lott',
#      'age': 31,
#      'gender': 'M',
#      'address': '456 Danforth Street',
#      'employer': 'Plasto',
#      'email': 'romerolott@plasto.com',
#      'city': 'Vincent',
#      'state': 'VT'}}]}}

# %% [markdown]
# ## Analyze results with aggregations
# Elasticsearch aggregations enable you to get meta-information about your search results and answer questions like, "How many account holders are in Texas?" or "What’s the average balance of accounts in Tennessee?" You can search documents, filter hits, and use aggregations to analyze the results all in one request.
#
# For example, the following request uses a terms aggregation to group all of the accounts in the bank index by state, and returns the ten states with the most accounts in descending order:

# %%
data = """{
  "size": 0,
  "aggs": {
    "group_by_state": {
      "terms": {
        "field": "state.keyword"
      }
    }
  }
}"""

url="http://localhost:9200/bank/_search?pretty"

headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}

r = requests.post(url,data=data, headers=headers)
r.json()
# Out:
# {'took': 64,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1000, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'group_by_state': {'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 743,
#    'buckets': [{'key': 'TX', 'doc_count': 30},
#     {'key': 'MD', 'doc_count': 28},
#     {'key': 'ID', 'doc_count': 27},
#     {'key': 'AL', 'doc_count': 25},
#     {'key': 'ME', 'doc_count': 25},
#     {'key': 'TN', 'doc_count': 25},
#     {'key': 'WY', 'doc_count': 25},
#     {'key': 'DC', 'doc_count': 24},
#     {'key': 'MA', 'doc_count': 24},
#     {'key': 'ND', 'doc_count': 24}]}}}

# %% [markdown]
# You can combine aggregations to build more complex summaries of your data. For example, the following request nests an avg aggregation within the previous group_by_state aggregation to calculate the average account balances for each state.

# %%
data = """{
  "size": 0,
  "aggs": {
    "group_by_state": {
      "terms": {
        "field": "state.keyword"
      },
      "aggs": {
        "average_balance": {
          "avg": {
            "field": "balance"
          }
        }
      }
    }
  }
}"""

url="http://localhost:9200/bank/_search?pretty"

headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}

r = requests.post(url,data=data, headers=headers)
r.json()
# Out:
# {'took': 22,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1000, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'group_by_state': {'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 743,
#    'buckets': [{'key': 'TX',
#      'doc_count': 30,
#      'average_balance': {'value': 26073.3}},
#     {'key': 'MD',
#      'doc_count': 28,
#      'average_balance': {'value': 26161.535714285714}},
#     {'key': 'ID',
#      'doc_count': 27,
#      'average_balance': {'value': 24368.777777777777}},
#     {'key': 'AL', 'doc_count': 25, 'average_balance': {'value': 25739.56}},
#     {'key': 'ME', 'doc_count': 25, 'average_balance': {'value': 21663.0}},
#     {'key': 'TN', 'doc_count': 25, 'average_balance': {'value': 28365.4}},
#     {'key': 'WY', 'doc_count': 25, 'average_balance': {'value': 21731.52}},
#     {'key': 'DC',
#      'doc_count': 24,
#      'average_balance': {'value': 23180.583333333332}},
#     {'key': 'MA',
#      'doc_count': 24,
#      'average_balance': {'value': 29600.333333333332}},
#     {'key': 'ND',
#      'doc_count': 24,
#      'average_balance': {'value': 26577.333333333332}}]}}}

# %% [markdown]
# Instead of sorting the results by count, you could sort using the result of the nested aggregation by specifying the order within the terms aggregation:

# %%
data = """{
  "size": 0,
  "aggs": {
    "group_by_state": {
      "terms": {
        "field": "state.keyword",
        "order": {
          "average_balance": "desc"
        }
      },
      "aggs": {
        "average_balance": {
          "avg": {
            "field": "balance"
          }
        }
      }
    }
  }
}"""

url="http://localhost:9200/bank/_search?pretty"

headers = {'Content-type': 'application/json', 'Accept': 'text/plain'}

r = requests.post(url,data=data, headers=headers)
r.json()
# Out:
# {'took': 13,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 1000, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []},
#  'aggregations': {'group_by_state': {'doc_count_error_upper_bound': -1,
#    'sum_other_doc_count': 827,
#    'buckets': [{'key': 'CO',
#      'doc_count': 14,
#      'average_balance': {'value': 32460.35714285714}},
#     {'key': 'NE', 'doc_count': 16, 'average_balance': {'value': 32041.5625}},
#     {'key': 'AZ',
#      'doc_count': 14,
#      'average_balance': {'value': 31634.785714285714}},
#     {'key': 'MT',
#      'doc_count': 17,
#      'average_balance': {'value': 31147.41176470588}},
#     {'key': 'VA', 'doc_count': 16, 'average_balance': {'value': 30600.0625}},
#     {'key': 'GA', 'doc_count': 19, 'average_balance': {'value': 30089.0}},
#     {'key': 'MA',
#      'doc_count': 24,
#      'average_balance': {'value': 29600.333333333332}},
#     {'key': 'IL',
#      'doc_count': 22,
#      'average_balance': {'value': 29489.727272727272}},
#     {'key': 'NM',
#      'doc_count': 14,
#      'average_balance': {'value': 28792.64285714286}},
#     {'key': 'LA',
#      'doc_count': 17,
#      'average_balance': {'value': 28791.823529411766}}]}}}

# %% [markdown]
# ## Client Library

# %% [markdown]
# ### Install

# %%
# !pip install elasticsearch
# Out:
# Collecting elasticsearch
#   Downloading elasticsearch-7.7.0-py2.py3-none-any.whl (99 kB)
#      |████████████████████████████████| 99 kB 805 kB/s eta 0:00:01
# Requirement already satisfied: urllib3>=1.21.1 in /home/nics/anaconda3/lib/python3.7/site-packages (from elasticsearch) (1.25.8)
# Requirement already satisfied: certifi in /home/nics/anaconda3/lib/python3.7/site-packages (from elasticsearch) (2020.4.5.1)
# Installing collected packages: elasticsearch
# Successfully installed elasticsearch-7.7.0

# %% [markdown]
# ### Import

# %%
from elasticsearch import Elasticsearch

# %%
# by default we connect to localhost:9200
es = Elasticsearch()

es.get(index="bank", id=1)
# Out:
# {'_index': 'bank',
#  '_type': '_doc',
#  '_id': '1',
#  '_version': 1,
#  '_seq_no': 0,
#  '_primary_term': 1,
#  'found': True,
#  '_source': {'account_number': 1,
#   'balance': 39225,
#   'firstname': 'Amber',
#   'lastname': 'Duke',
#   'age': 32,
#   'gender': 'M',
#   'address': '880 Holmes Lane',
#   'employer': 'Pyrami',
#   'email': 'amberduke@pyrami.com',
#   'city': 'Brogan',
#   'state': 'IL'}}

# %% [markdown]
# ![](https://i.imgflip.com/41pml7.jpg)
# [NicsMeme](https://imgflip.com/i/41pml7)

# %% [markdown]
#  # Demo Time
#
#  https://www.elastic.co/customers/
#
#  * Exaudi Funnel
#  * ad.agio

# %% [markdown]
# # Biblio

# %% [markdown]
# * https://www.elastic.co/guide/en/elasticsearch/reference/current/docs.html
# * https://plotly.com/python/getting-started/
